# %%
# !pip install bottleneck
# !pwd
# Out:
# ...
#      |████████████████████████████████| 88 kB 2.5 MB/s eta 0:00:011
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for bottleneck: filename=Bottleneck-1.3.2-cp37-cp37m-linux_x86_64.whl size=335095 sha256=74dd7f5f466119df24aeb6c444fa85f36477e10ed5fb6c9d19814db0481e4f2d
#   Stored in directory: /home/msbd/.cache/pip/wheels/87/85/9c/a325c89ff0498660ef8a335fb4b3912939c273ea4f094af29f
# Successfully built bottleneck
# ...
# /home/msbd/msbd5016/Sets2Sets

# %% [markdown]
# Sets2Sets only runs on an older torch version

# %%
# !pip install torch==1.0.1 
# !pip install torchvision==0.2.2
# Out:
# ...
#   Using cached torch-1.0.1-cp37-cp37m-manylinux1_x86_64.whl (560.1 MB)
# ...
#   Attempting uninstall: torch
#     Found existing installation: torch 1.4.0
#     Uninstalling torch-1.4.0:
#       Successfully uninstalled torch-1.4.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.5.0 requires torch==1.4.0, but you have torch 1.0.1 which is incompatible.
# ...
#      |████████████████████████████████| 64 kB 604 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 52 kB 76 kB/s s eta 0:00:01
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.60.0
#     Uninstalling tqdm-4.60.0:
#       Successfully uninstalled tqdm-4.60.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.5.0
#     Uninstalling torchvision-0.5.0:
#       Successfully uninstalled torchvision-0.5.0
# ...

# %% [markdown]
# Tried to use some existing function showPlot in the code base to visualize the training loss but unfortunately the function was not defined anywhere :(

# %%
import time 
start_time = time.time()
# !python ./Sets2Sets.py ./data/TaFang_history.csv ./data/TaFang_future.csv TaFang 2 1
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# start dictionary generation...
# {'MATERIAL_NUMBER': 5000}
# # dimensions of final vector: 5000 | 160
# finish dictionary generation*****
# num of vectors having entries more than 1: 33145
# num of vectors having entries more than 1: 33567
# Number of training instances: 5116
# 3m 25s (- 167m 32s) (5116 2%) 1358.706466
# Finish epoch: 0
# Model is saved.
# 6m 55s (- 166m 17s) (10232 4%) 1354.949761
# Finish epoch: 1
# Model is saved.
# 10m 21s (- 162m 24s) (15348 6%) 1346.046708
# Finish epoch: 2
# Model is saved.
# 13m 48s (- 158m 42s) (20464 8%) 1334.181259
# Finish epoch: 3
# Model is saved.
# 17m 11s (- 154m 47s) (25580 10%) 1323.860144
# Finish epoch: 4
# Model is saved.
# 20m 38s (- 151m 22s) (30696 12%) 1315.065488
# Finish epoch: 5
# Model is saved.
# 24m 4s (- 147m 51s) (35812 14%) 1306.441709
# Finish epoch: 6
# Model is saved.
# 27m 29s (- 144m 20s) (40928 16%) 1298.260147
# Finish epoch: 7
# Model is saved.
# 30m 55s (- 140m 52s) (46044 18%) 1292.065364
# Finish epoch: 8
# ...

# %% [markdown]
# Lots of nans here. Not good :(

# %%
start_time = time.time()
# !python ./Sets2Sets.py ./data/TaFang_history.csv ./data/TaFang_future.csv TaFang 2 0 
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# start dictionary generation...
# {'MATERIAL_NUMBER': 5000}
# # dimensions of final vector: 5000 | 160
# finish dictionary generation*****
# num of vectors having entries more than 1: 33145
# num of vectors having entries more than 1: 33567
# Number of training instances: 5116
# k = 20
# Epoch:  0
# average precision of subsequent sets: 0.03868838028169014 with std: 0.049798411283800983
# average recall: 0.1510702222868001 with std: 0.2409233341343733
# average F score of subsequent sets: 0.053809332621579865 with std: 0.06504428029381464
# average precision of 1st: 0.03961267605633803 with std: 0.04890913515172218
# average recall of 1st: 0.1515137677945402 with std: 0.2393274234086347
# average F score of 1st: 0.05505241220614297 with std: 0.064474164563032
# average precision of 2nd: 0.03776408450704226 with std: 0.05065522071942539
# average recall of 2nd: 0.15062667677906003 with std: 0.24250793141708796
# average F score of 2nd: 0.05256625303701675 with std: 0.06558588573826385
# ...
