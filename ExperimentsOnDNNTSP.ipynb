# %% [markdown]
# Install libraries for enabling GPU

# %%
# !pip install dgl-cu100
# !pip install tensorboardX

# %% [markdown]
# Python Issue faced while truing to build DNNTSP. This happens becasue some packages are unable to reference packages located in their parent directories. So in order to run the train python script we need to navigate to the train directory.
#
# We also added a syspath reference to the parent directory in train_main.py. train_main.py was unable to find utils package located in the parent directory.
#
# Code that was added
#
# `
# import os
# import sys
# sys.path.append(os.path.abspath('..'))
# `

# %%
# %cd DNNTSP/train/
# !pwd
# Out:
# /home/msbd/msbd5016/DNNTSP/train
# /home/msbd/msbd5016/DNNTSP/train

# %% [markdown]
# We ran an older torch version 1.0.1 for Sets2Sets

# %%
# !pip install --upgrade torch

# %% [markdown]
# Note - for every train/test run of DNNTSP we will keep track of time for performance purposes. We will plot some of these charts in our reports
#
# ***
# BASELINE MODEL
# ***

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_19.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %% [markdown]
# Experiment #1 We alter learning rate to 0.003

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_10.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %% [markdown]
# Experiment #2 We try a small learning rate of 0.0001 (1/10x)

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_0.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %% [markdown]
# Experiment #3 LR of 0.002

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_9.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): ReLU()
#         (1): ReLU()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %% [markdown]
# Experiment #5
# ***
# Now we try to change the activation fucntion to LeakyReLU and Sigmoid
# ***
# First is Leaky ReLU

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): LeakyReLU(negative_slope=0.1)
#         (1): LeakyReLU(negative_slope=0.1)
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_14.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): LeakyReLU(negative_slope=0.1)
#         (1): LeakyReLU(negative_slope=0.1)
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
# ...

# %% [markdown]
# ***
# Another round of LeakyReLU since the last round did not conver with 15 epochs and was still producing better models
# ***

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): LeakyReLU(negative_slope=0.1)
#         (1): LeakyReLU(negative_slope=0.1)
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_24.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): LeakyReLU(negative_slope=0.1)
#         (1): LeakyReLU(negative_slope=0.1)
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
# ...

# %% [markdown]
# Experiment #6
# ***
# Sigmoid
# ***

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): Sigmoid()
#         (1): Sigmoid()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_14.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): Sigmoid()
#         (1): Sigmoid()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): Sigmoid()
#         (1): Sigmoid()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_13.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): Sigmoid()
#         (1): Sigmoid()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %% [markdown]
# ***
# Now we try with GPU Disabled
# ***

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/train/train_main.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# TaFeng/DNNTSP
# train data length -> 6888
# validate data length -> 984
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): Sigmoid()
#         (1): Sigmoid()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...

# %%
import time 
start_time = time.time() 
# !python ~/msbd5016/DNNTSP/test/testing_model.py
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Using backend: pytorch
# model path -> ../save_model_folder/TaFeng/DNNTSP/model_epoch_10.pkl
# TaFeng/DNNTSP
# temporal_set_prediction(
#   (item_embedding): Embedding(4935, 32)
#   (stacked_gcn): stacked_weighted_GCN_blocks(
#     (0): weighted_GCN(
#       (gcns): ModuleList(
#         (0): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#         (1): weighted_graph_conv(
#           (linear): Linear(in_features=32, out_features=32, bias=True)
#         )
#       )
#       (relus): ModuleList(
#         (0): Sigmoid()
#         (1): Sigmoid()
#       )
#       (bns): ModuleList(
#         (0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (1): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (masked_self_attention): masked_self_attention(
#     (Wq): Linear(in_features=32, out_features=32, bias=False)
# ...
